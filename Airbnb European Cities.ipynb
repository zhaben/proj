# %% [markdown]
# # Airbnb European Cities

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/thedevastator/airbnb-prices-in-european-cities?resource=download

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os_files = os.listdir("/Users/zhanebennett/Downloads/archive")

# %%
dfs = []
path = "/Users/zhanebennett/Downloads/archive"

for file in os_files:
    df = pd.read_csv(os.path.join(path, file))
    df['City'] = file.split('_')[0]
    df['Time_of_week'] = file.split('_')[1][:-4]
    dfs.append(df) #list of dataframes

# %%
df_combined = pd.concat(dfs)

# %%
df_combined.drop(columns=df_combined.columns[0], axis=1, inplace=True)

# %%
df = df_combined.copy()

# %%
df.head()
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  344.245776  Private room        False          True              4.0
# 2  264.101422  Private room        False          True              2.0
# 3  433.529398  Private room        False          True              4.0
# 4  485.552926  Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    0                 8.0
# 2              False      0    1                 9.0
# 3              False      0    1                 9.0
# 4               True      0    0                10.0
#
#    guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 0                        93.0  ...  5.022964    2.539380   78.690379
# 1                        85.0  ...  0.488389    0.239404  631.176378
# 2                        87.0  ...  5.748312    3.651621   75.275877
# 3                        90.0  ...  0.384862    0.439876  493.272534
# 4                        98.0  ...  0.544738    0.318693  552.830324
#
#    attr_index_norm  rest_index  rest_index_norm      lng       lat       City  \
# 0         4.166708   98.253896         6.846473  4.90569  52.41772  amsterdam
# 1        33.421209  837.280757        58.342928  4.90005  52.37432  amsterdam
# 2         3.985908   95.386955         6.646700  4.97512  52.36103  amsterdam
# 3        26.119108  875.033098        60.973565  4.89417  52.37663  amsterdam
# 4        29.272733  815.305740        56.811677  4.90051  52.37508  amsterdam
#
#   Time_of_week
# 0     weekdays
# 1     weekdays
# 2     weekdays
# 3     weekdays
# 4     weekdays
#
# [5 rows x 21 columns]

# %%
x = df['City']
y = df['realSum']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))

plt.title('Airbnb Average Price per City', fontsize=20)
plt.xlabel('City', fontsize=16);
plt.ylabel('Price', fontsize=16);
plt.xticks(fontsize=14, rotation=15);
 
# Horizontal Bar Plot
plt.bar(x, y)
 
# Show Plot
plt.show()

# %%
x = df['Time_of_week']
y = df['realSum']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.title('Airbnb Average Price per Time of Week', fontsize=20)
plt.xlabel('Day of Week', fontsize=16);
plt.ylabel('Price', fontsize=16);
plt.xticks(fontsize=14, rotation=0);
 
# Horizontal Bar Plot
plt.bar(x, y)

# Show Plot
plt.show()

# %%
x = df['cleanliness_rating']
y = df['metro_dist']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
plt.title('Airbnb Average Distane from City Center per Cleanliness Rating', fontsize=20)
plt.xlabel('Cleanliness Rating', fontsize=16);
plt.ylabel('Distance from City Center', fontsize=16);
plt.xticks(fontsize=14, rotation=0);  
    
# Horizontal Bar Plot
plt.bar(x, y)

# Show Plot
plt.show()

# %%
x = df['City']
y = df['dist']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(x, y)

plt.title('Airbnb Average Distance from City Center per City', fontsize=20)
plt.xlabel('City', fontsize=16);
plt.ylabel('Distance', fontsize=16);
plt.xticks(fontsize=14, rotation=15);

# Show Plot
plt.show()

# %%
import seaborn as sns
grouped_city = df.groupby(['City', 'Time_of_week'])['realSum'].mean().reset_index()
grouped_city

sns.barplot(data=grouped_city, x = 'realSum', y = "City", hue = "Time_of_week");

plt.title('Airbnb Average Price per City per Time of Week', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'Time_of_week'])['dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'dist', y = "City")

plt.title('Airbnb Average Distance from City Center per City', fontsize=20)
plt.xlabel('Distance from City Center', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'Time_of_week'])['metro_dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'metro_dist', y = "City")#, hue="Time_of_week");

plt.title('Airbnb Average Distance from Metro per City', fontsize=20)
plt.xlabel('Distance from Metro', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'Time_of_week'])['metro_dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'metro_dist', y = "City", hue="Time_of_week");

plt.title('Airbnb Average Distance from Metro per City per Time of Week', fontsize=20)
plt.xlabel('Distance from Metro', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'room_type'])['dist'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'dist', y = "City", hue='room_type');

plt.title('Airbnb Average Distance from City Center per City per Room Type', fontsize=20)
plt.xlabel('Distance from City Center', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
grouped_1 = df.groupby(['City', 'room_type'])['realSum'].mean().reset_index()
grouped_1
sns.barplot(data=grouped_1, x = 'realSum', y = "City", hue='room_type');

plt.title('Airbnb Average Price per City per Room Type', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %% [markdown]
# ## Scatter Plots

# %%
bx = df.plot(kind='scatter', x='dist',y='realSum',color = 'Green',label ='f')

# %%
sns.scatterplot(data=df[df['realSum'] < 3000], x = 'metro_dist', y = "realSum", hue = "City", alpha=.2)

#df_combined[df_combined['real_sum'] < 5000]
# Out:
# <AxesSubplot:xlabel='metro_dist', ylabel='realSum'>

# %%
sns.scatterplot(data=df[(df['realSum'] < 5000) & (df['City'] == "vienna")], x = 'metro_dist', y = "realSum", hue = "City")
# Out:
# <AxesSubplot:xlabel='metro_dist', ylabel='realSum'>

# %%
g = sns.FacetGrid(df, col="City")
g.map_dataframe(sns.scatterplot, x="dist", y="realSum")

# %% [markdown]
# # Histograms

# %%
df.hist(bins=30, figsize=(15, 10));

# %% [markdown]
# # Correlation Matrices

# %%
#plt.matshow(df.corr())
#plt.show()

f = plt.figure(figsize=(8, 6))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=10, rotation=75)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=10)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
import pandas as pd
import numpy as np

#rs = np.random.RandomState(0)
#df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')

################################################
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null('#f1f1f1')  # Color NaNs grey
 .format(precision=2))
# Out:
# <style type="text/css">
# #T_1faa7_row0_col0, #T_1faa7_row0_col1, #T_1faa7_row0_col2, #T_1faa7_row0_col3, #T_1faa7_row0_col4, #T_1faa7_row0_col5, #T_1faa7_row0_col6, #T_1faa7_row0_col7, #T_1faa7_row0_col8, #T_1faa7_row0_col9, #T_1faa7_row0_col10, #T_1faa7_row0_col11, #T_1faa7_row0_col12, #T_1faa7_row0_col13, #T_1faa7_row0_col14, #T_1faa7_row0_col15, #T_1faa7_row0_col16, #T_1faa7_row0_col17, #T_1faa7_row1_col1, #T_1faa7_row1_col2, #T_1faa7_row1_col3, #T_1faa7_row1_col4, #T_1faa7_row1_col5, #T_1faa7_row1_col6, #T_1faa7_row1_col7, #T_1faa7_row1_col8, #T_1faa7_row1_col9, #T_1faa7_row1_col10, #T_1faa7_row1_col11, #T_1faa7_row1_col12, #T_1faa7_row1_col13, #T_1faa7_row1_col14, #T_1faa7_row1_col15, #T_1faa7_row1_col16, #T_1faa7_row1_col17, #T_1faa7_row2_col2, #T_1faa7_row2_col3, #T_1faa7_row2_col4, #T_1faa7_row2_col5, #T_1faa7_row2_col6, #T_1faa7_row2_col7, #T_1faa7_row2_col8, #T_1faa7_row2_col9, #T_1faa7_row2_col10, #T_1faa7_row2_col11, #T_1faa7_row2_col12, #T_1faa7_row2_col13, #T_1faa7_row2_col14, #T_1faa7_row2_col15, #T_1faa7_row2_col16, #T_1faa7_row2_col17, #T_1faa7_row3_col3, #T_1faa7_row3_col4, #T_1faa7_row3_col5, #T_1faa7_row3_col6, #T_1faa7_row3_col7, #T_1faa7_row3_col8, #T_1faa7_row3_col9, #T_1faa7_row3_col10, #T_1faa7_row3_col11, #T_1faa7_row3_col12, #T_1faa7_row3_col13, #T_1faa7_row3_col14, #T_1faa7_row3_col15, #T_1faa7_row3_col16, #T_1faa7_row3_col17, #T_1faa7_row4_col4, #T_1faa7_row4_col5, #T_1faa7_row4_col6, #T_1faa7_row4_col7, #T_1faa7_row4_col8, #T_1faa7_row4_col9, #T_1faa7_row4_col10, #T_1faa7_row4_col11, #T_1faa7_row4_col12, #T_1faa7_row4_col13, #T_1faa7_row4_col14, #T_1faa7_row4_col15, #T_1faa7_row4_
{
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_1faa7_row13_col4, #T_1faa7_row16_col6, #T_1faa7_row

# %%
#List of correlated values
df.corr().unstack().sort_values().drop_duplicates()
# Out:
# person_capacity             room_private         -0.499993
# biz                         multi                -0.470725
# rest_index_norm             dist                 -0.467791
# attr_index                  dist                 -0.363088
# dist                        rest_index           -0.346653
#                                                     ...
# rest_index_norm             rest_index            0.617970
# guest_satisfaction_overall  cleanliness_rating    0.714045
# attr_index                  attr_index_norm       0.714847
# rest_index                  attr_index            0.850229
# realSum                     realSum               1.000000
# Length: 154, dtype: float64

# %%
#List of correlated values - absolute value
df.corr().abs().unstack().sort_values().drop_duplicates()
# Out:
# multi               bedrooms                      0.000659
# metro_dist          host_is_superhost             0.000722
# realSum             guest_satisfaction_overall    0.001888
# metro_dist          room_shared                   0.002868
# person_capacity     cleanliness_rating            0.003256
#                                                     ...
# rest_index          rest_index_norm               0.617970
# cleanliness_rating  guest_satisfaction_overall    0.714045
# attr_index_norm     attr_index                    0.714847
# rest_index          attr_index                    0.850229
# realSum             realSum                       1.000000
# Length: 154, dtype: float64

# %% [markdown]
# # Bar Plot

# %%
df[['room_type', 'guest_satisfaction_overall']].hist(by='room_type', figsize=(18, 12))
# Out:
# array([[<AxesSubplot:title={'center':'Entire home/apt'}>,
#         <AxesSubplot:title={'center':'Private room'}>],
#        [<AxesSubplot:title={'center':'Shared room'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df_sns = df.reset_index()

# %%
df.groupby('host_is_superhost')['guest_satisfaction_overall'].mean().plot(kind='bar', rot=45, fontsize=10, figsize=(4, 3))
# Out:
# <AxesSubplot:xlabel='host_is_superhost'>

# %%
o = df[df['realSum'].notnull()]
pivot = pd.pivot_table(data=o, index=['host_is_superhost'], columns=['room_type'], values='realSum')
pivot
# Out:
# room_type          Entire home/apt  Private room  Shared room
# host_is_superhost
# False                   341.279766     205.54976   140.967040
# True                    279.354366     202.86695   164.168972

# %%
ax = pivot.plot.bar(stacked=True, figsize=(8,6))
ax.set_title('Price per Room Time per Time of Week', fontsize=20)
ax.set_ylim(0,500)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);

# %%
df.groupby('room_type')['guest_satisfaction_overall'].mean().plot(kind='bar', rot=45, fontsize=10, figsize=(4, 3))
# Out:
# <AxesSubplot:xlabel='room_type'>

# %%
pivot = pd.pivot_table(data=df, index=['room_type'], columns=['Time_of_week'], values='realSum')
pivot
# Out:
# Time_of_week       weekdays    weekends
# room_type
# Entire home/apt  320.083367  328.379227
# Private room     202.169874  207.698465
# Shared room      139.105184  147.883241

# %%
ax = pivot.plot.bar(stacked=True, color =['lightseagreen', 'tomato'], figsize=(12,6))
ax.set_title('Price per Room Time per Time of Week', fontsize=20)
ax.set_ylim(0,500)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0);

# %% [markdown]
# # Stats visuals

# %%
df.count()
# Out:
# realSum                       51707
# room_type                     51707
# room_shared                   51707
# room_private                  51707
# person_capacity               51707
# host_is_superhost             51707
# multi                         51707
# biz                           51707
# cleanliness_rating            51707
# guest_satisfaction_overall    51707
# bedrooms                      51707
# dist                          51707
# metro_dist                    51707
# attr_index                    51707
# attr_index_norm               51707
# rest_index                    51707
# rest_index_norm               51707
# lng                           51707
# lat                           51707
# City                          51707
# Time_of_week                  51707
# dtype: int64

# %% [markdown]
# ## Manage Outliers

# %%
#Outliers

outliers = df[['realSum']].dropna()
df_outliers = df.loc[outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]
#outliers2.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)
df_outliers.head()
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  344.245776  Private room        False          True              4.0
# 2  264.101422  Private room        False          True              2.0
# 3  433.529398  Private room        False          True              4.0
# 4  485.552926  Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    0                 8.0
# 2              False      0    1                 9.0
# 3              False      0    1                 9.0
# 4               True      0    0                10.0
#
#    guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 0                        93.0  ...  5.022964    2.539380   78.690379
# 1                        85.0  ...  0.488389    0.239404  631.176378
# 2                        87.0  ...  5.748312    3.651621   75.275877
# 3                        90.0  ...  0.384862    0.439876  493.272534
# 4                        98.0  ...  0.544738    0.318693  552.830324
#
#    attr_index_norm  rest_index  rest_index_norm      lng       lat       City  \
# 0         4.166708   98.253896         6.846473  4.90569  52.41772  amsterdam
# 1        33.421209  837.280757        58.342928  4.90005  52.37432  amsterdam
# 2         3.985908   95.386955         6.646700  4.97512  52.36103  amsterdam
# 3        26.119108  875.033098        60.973565  4.89417  52.37663  amsterdam
# 4        29.272733  815.305740        56.811677  4.90051  52.37508  amsterdam
#
#   Time_of_week
# 0     weekdays
# 1     weekdays
# 2     weekdays
# 3     weekdays
# 4     weekdays
#
# [5 rows x 21 columns]

# %%
df_outliers.count()
# Out:
# realSum                       51304
# room_type                     51304
# room_shared                   51304
# room_private                  51304
# person_capacity               51304
# host_is_superhost             51304
# multi                         51304
# biz                           51304
# cleanliness_rating            51304
# guest_satisfaction_overall    51304
# bedrooms                      51304
# dist                          51304
# metro_dist                    51304
# attr_index                    51304
# attr_index_norm               51304
# rest_index                    51304
# rest_index_norm               51304
# lng                           51304
# lat                           51304
# City                          51304
# Time_of_week                  51304
# dtype: int64

# %%
# Dataframe is now without outliers
df = df_outliers.copy()

# %%
normalized_df=(df-df.mean())/df.std() #mean
#normalized_df=(df-df.min())/(df.max()-df.min()) #max_min
# Out:
# /var/folders/vg/kzyxthxd3s52ww15y_mt_5rc0000gn/T/ipykernel_92637/1023475572.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   normalized_df=(df-df.mean())/df.std() #mean
# /var/folders/vg/kzyxthxd3s52ww15y_mt_5rc0000gn/T/ipykernel_92637/1023475572.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   normalized_df=(df-df.mean())/df.std() #mean

# %%
boxplot = normalized_df.boxplot(figsize=(15, 8))

plt.title('Box & Whisker Plot of Features', fontsize=20)
plt.xlabel('Features', fontsize=10);
plt.xticks(fontsize=10, rotation=75);

# %% [markdown]
# # Scatter Plot

# %%
from pandas.plotting import scatter_matrix
  
# selecting three numerical features
features = ['realSum','dist', 'metro_dist']
   
#plotting the scatter matrix
#with the features
scatter_matrix(df[features])
plt.show()

# %%
df[['realSum']].plot(kind='hist', density=True,                            
        alpha=0.7,
        bins=100,
        title='Distribution Of Price',
        rot=45,
        grid=True,
        figsize=(12,8),
        fontsize=15, 
        color=['#A0E8AF', '#FFCF56'])
plt.xlabel('Price')
plt.ylabel("Number of Airbnb Rentals");

# %%
df_sns = df.reset_index()

# %%
import seaborn as sns
# Set figure size for the notebook
plt.rcParams["figure.figsize"]=12,8

# set seaborn whitegrid theme
sns.set(style="whitegrid")

sns.kdeplot(data=df_sns, x="realSum", hue="City", fill=True, common_norm=False, alpha=0.3)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="realSum", hue="room_type", fill=True, common_norm=False, alpha=0.4)
plt.show()

# %%
# using small multiple
# create a grid 
g = sns.FacetGrid(df_sns, col='room_type', hue='room_type', col_wrap=3)

# draw density plots
g = g.map(sns.kdeplot,"realSum", cut=0, fill=True, common_norm=False, alpha=1, legend=False)

# control the title of each facet
g = g.set_titles("{col_name}")

# show the graph
plt.show()

# %%
# using small multiple
# create a grid 
g = sns.FacetGrid(df_sns, col='City', hue='room_type', col_wrap=3)

# draw density plots
g = g.map(sns.kdeplot,"realSum", cut=0, fill=True, common_norm=False, alpha=.4, legend=False)

# control the title of each facet
g = g.set_titles("{col_name}")

# show the graph
plt.show()

# %%
sns.kdeplot(data=df_sns, x="dist", hue="City", fill=True, common_norm=False, alpha=0.2)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="metro_dist", hue="City", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="realSum", hue="room_private", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
sns.kdeplot(data=df_sns, x="realSum", hue="cleanliness_rating", fill=True, common_norm=False, alpha=0.1)
plt.show()

# %%
# stacked density plot
sns.kdeplot(data=df, x="realSum", hue="bedrooms", common_norm=False, multiple="fill", alpha=1)

# show the graph
plt.show()

# %%
# stacked density plot
sns.kdeplot(data=df, x="realSum", hue="host_is_superhost", fill=True, common_norm=False, alpha=.1)

# show the graph
plt.show()

# %% [markdown]
# # Box & Whisker Plots

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data = df, x="City", y="realSum")
'''
#Adjusted for prices under $5,000 instead of outlier
plt.figure(figsize=(15,8))
sns.boxplot(data = df[df['realSum'] < 5000], x="City", y="realSum")
'''

plt.title('Dsitribution of Prices per City', fontsize=20)
plt.xlabel('City', fontsize=16);
plt.ylabel('Price', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
#Box & Whisker Plot Prices per City per Room Type
plt.figure(figsize=(15,8))
sns.boxplot(data = df, 
            x="realSum", 
            y="City", 
            hue="room_type")

plt.title('Distribution of Prices per City per Room Type', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %%
#Box & Whisker per Host Status
plt.figure(figsize=(15,8))
sns.boxplot(data = df, 
            x="realSum", 
            y="City", 
            hue="host_is_superhost",
           width=.7)

plt.title('Distribution of Prices per City per Super Host Status', fontsize=20)
plt.xlabel('Price', fontsize=16);
plt.ylabel('City', fontsize=16);
plt.xticks(fontsize=14, rotation=0);

# %% [markdown]
# # MAPS... (next document)
